# %% [markdown]
# # Welcome to Lab: Experimental Design 👨‍🔬⚗️🧪
#
# Before this lab section, you completed the "Hello Survey" based on the questions you generated with your groups.  This week, you will do an analysis of the results and explore techniques to do great experimental design in Python!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = ""
ca1_name = ""
ca2_name = ""
ca3_name = ""

# Say hello to each other!
# - Groups of 3 are ideal :)
# - However groups of 2 or 4 are fine too!
partner1_name = "Melissa"
partner1_netid = ""
partner1_inYourGroupLastWeek = "yes"

partner2_name = "Gaby"
partner2_netid = ""
partner2_inYourGroupLastWeek = "yes"

partner3_name = ""
partner3_netid = ""
partner3_inYourGroupLastWeek = "yes"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello Dataset Analysis
#
# In lab last week, you created a series of questions that made up the **"Hello Dataset"**.  Before lab, you completed this survey along with the entire course.  Today, you're going to do analysis on this dataset! :)

# %% [markdown]
# ## Your Binary Question Analysis
#
# You will be analyzing the **binary question** your group asked the class from `lab_pandas` -- record it below.  If multiple people from your group had different binary questions, decide which one to use and record that question below.

# %% [markdown]
# *(✏️Edit this cell to add your group's question.✏️)*

# %% [markdown]
# ## Load the Hello Dataset
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-fa24.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df` -- and **don't forget to import pandas**! :)

# %%
import pandas as pd

df = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-fa24.csv")
df
# Out:
#              Name       Lab When flipping a coin, heads or tails?  \
# 0     Prof. Karle  AL1, AL2                                 Heads
# 1      Prof. Wade  AL1, AL2                                 Tails
# 2        Angelina       Y13                                 Tails
# 3        TA Tyler       Y07                                 Tails
# 4          Sneha        Y17                                 Tails
# ...           ...       ...                                   ...
# 1065     Man Geun       Y04                                 Heads
# 1066     CA Elise  Y11, Y33                                 Heads
# 1067      Chinmay       Y11                                 Heads
# 1068        Bowen       Y25                                 Heads
# 1069     kaicheng       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 0                      Not First Year
# 1                      Not First Year
# 2                  First Year at UIUC
# 3                      Not First Year
# 4                  First Year at UIUC
# ...                               ...
# 1065                   Not First Year
# 1066                   Not First Year
# 1067               First Year at UIUC
# 1068               First Year at UIUC
# 1069               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 0                                             Chocolate
# 1                                               Vanilla
# 2                                               Vanilla
# 3                                             Chocolate
# 4                                               Vanilla
# ...                                                 ...
# 1065                                            Vanilla
# 1066                                            Vanilla
# 1067                                          Chocolate
# 1068                                          Chocolate
# 1069                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 0                             Night                               Even
# 1                             Night                                Odd
# 2                           Morning                               Even
# 3                             Night                               Even
# 4                             Night                               Even
# ...                             ...                                ...
# 1065                          Night                               Even
# 1066                          Night                               Even
# 1067                          Night                               Even
# 1068                          Night                                Odd
# 1069                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 0                    No                          Summer
# 1                   Yes                          Winter
# 2                   Yes                          Summer
# 3                    No                          Winter
# 4                    No                          Summer
# ...                 ...                             ...
# 1065                 No                          Winter
# 1066                Yes                          Summer
# 1067                 No                          Summer
# 1068                 No                          Summer
# 1069                 No                          Winter
#
#      Are you a business major?  ...  \
# 0                           No  ...
# 1                           No  ...
# 2                           No  ...
# 3                           No  ...
# 4                          Yes  ...
# ...                        ...  ...
# 1065                        No  ...
# 1066                        No  ...
# 1067                        No  ...
# 1068                        No  ...
# 1069                       Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 0                                          The Maldives
# 1                                                Sweden
# 2                                            Hong Kong
# 3                                                Canada
# 4                                                Canada
# ...                                                 ...
# 1065                                              Korea
# 1066                                            England
# 1067                                              India
# 1068                                              China
# 1069                                              china
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 0                            pink                         water skiing!
# 1                          Purple                           Programming
# 2                            Pink                        Watching shows
# 3                          Orange                              Terraria
# 4                           Green                 Reading or crocheting
# ...                           ...                                   ...
# 1065                         Blue                           Playstation
# 1066                         Pink                          With friends
# 1067                         Blue                                 Music
# 1068                       Purple                                 Films
# 1069                         blue                                 sleep
#
#      What genre of music do you like the most?  \
# 0                                          pop
# 1                                          Pop
# 2                                          r&b
# 3                                     Pop rock
# 4                                     Pop Rock
# ...                                        ...
# 1065                                       Pop
# 1066                                 Indie pop
# 1067                                       Rap
# 1068                                      Rocj
# 1069                                     R n B
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 0                                                 sloth
# 1                                                   Fox
# 2                                                 Tiger
# 3                                                   Bee
# 4                                               Penguin
# ...                                                 ...
# 1065                                                Dog
# 1066                                               Wolf
# 1067                                                Dog
# 1068                                              Puppy
# 1069                                                dog
#
#      What do you think is the hardest major at UIUC?  \
# 0                                   Computer Science
# 1                                   Computer Science
# 2                             Aerospace engineering
# 3                               Chemical Engineering
# 4                                   Computer Science
# ...                                              ...
# 1065                                              CS
# 1066                                            Eecs
# 1067                                Computer Science
# 1068                                     Engineering
# 1069                                              ds
#
#      Who is your favorite music artist?  \
# 0                          Taylor Swift
# 1                          Taylor Swift
# 2                         Ashley Alisha
# 3                            Billy Joel
# 4                       Imagine Dragons
# ...                                 ...
# 1065                                 IU
# 1066                       Taylor swift
# 1067                       Travis Scott
# 1068                         Kanye West
# 1069                           lil tjay
#
#      What's your favorite social media app?  \
# 0                                 Instagram
# 1                                   YouTube
# 2                                     Insta
# 3                                    Reddit
# 4                                 Instagram
# ...                                     ...
# 1065                              Instagram
# 1066                              Pinterest
# 1067                              Instagram
# 1068                                    ins
# 1069                               snapchat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 0                                            volleyball
# 1                                              Factorio
# 2                                                   NaN
# 3                                              Terraria
# 4                                            Beat Saber
# ...                                                 ...
# 1065                                              NBA2k
# 1066                                           Pinochle
# 1067                                             Tennis
# 1068                                     Stardew Valley
# 1069                                                mma
#
#      Where is your dream vacation spot?
# 0                          The Maldives
# 1                                Acadia
# 2                       Southern France
# 3                          My apartment
# 4                                 Italy
# ...                                 ...
# 1065                             Cancun
# 1066                              Kenya
# 1067                             Monaco
# 1068                              Tokyo
# 1069                            iceland
#
# [1070 rows x 150 columns]

# %% [markdown]
# ## Find The Variable for Your Question
#
# The command `df.columns.tolist()` will **list all of the columns (variables)** in a DataFrame.  Use `df.columns.tolist()` and read the output until you find the column name for your binary question.
#
# - You may see the message: `Output exceeds the __size limit__. Open the full output data __in a text editor__`
# - If you do, click the **`__in a text editor__`** link to open the whole list in a new tab. :)

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Lab',
#  'When flipping a coin, heads or tails?',
#  'Is this your first year at UIUC?',
#  'Is your favorite ice cream flavor chocolate or vanilla?',
#  'Do you like morning or night? ',
#  'Do you prefer even or odd numbers?',
#  'Do you have a pet?',
#  'Do you prefer summer or winter?',
#  'Are you a business major?',
#  'Do you prefer Movies or TV shows?',
#  'Do you prefer pizza or hamburgers?',
#  'Are you male or female?',
#  'Do you prefer the color Blue or Red?',
#  'Do you like Taylor Swifts music?',
#  'Do you prefer sweet or salty food?',
#  'Do you eat breakfast in the mornings?',
#  'Ice cream or cake? ',
#  'Are you an upperclassman or an underclassman?',
#  'As you walk in from the back, do you prefer to sit on the left or right side of lecture?',
#  'Is the day of the month of your birthday an odd or even number?',
#  'Do you speak a second language?',
#  'Do you prefer cats or dogs?',
#  'Are you a morning person or a night person?',
#  'Do you enjoy reading?',
#  'Do you prefer milk chocolate or dark chocolate?',
#  'Do you prefer Italian or Mexican food?',
#  'Do you prefer sugar cookies or chocolate chip cookies?',
#  'Can you speak a second language fluently?',
#  'Do you prefer Math or English?',
#  'Do you like apples or bananas?',
#  'Waffles or pancakes?',
#  'Do you prefer day or night?',
#  'Do you prefer lecture halls or small classes? ',
#  'Are you in-state or out of state?',
#  'Do you typically shower in the morning or at night?',
#  'Does money buy happiness?',
#  'Do you prefer to party or stay in?',
#  'McDonalds or Burger King?',
#  'Do you prefer sweet or savory food?',
#  'What month is your birthday?',
#  'Do you drink a cup of coffee every morning?',
#  'Do you drink coffee?',
#  'Do you use a Mac or Windows Laptop?',
#  'Do you prefer brownies or cookies?',
#  'Google Docs or Microsoft Word?',
#  'Do you like horror movies?',
#  'Do you have programming experience?',
#  'Do you like pizza or pasta?',
#  'Do you wear glasses?',
#  'Do you like your dorm?',
#  'Fall or spring season?',
#  'Do you prefer pink or blue?',
#  'Are you from the Chicagoland area?',
#  'Does your NetID end with an even or odd number?',
#  'Are you wearing something on your wrist currently?',
#  'Is it called Futbol or Soccer?',
#  'Do you use corrective lenses (contacts/glasses)?',
#  'Do you prefer Apple Music or Spotify?',
#  'Do you have exactly one sibling?',
#  'Are you taking any other computer science classes?',
#  'In the DISCOVERY lecture, do you sit in the front 50% or back 50%?',
#  'Do you sit on the left or right side in lecture?',
#  'Pick a random number 1-10. is the number you picked odd or even?',
#  'Are you from Chicago?',
#  'Pick a number: One or Two.',
#  'Do you prefer to study alone or in groups?',
#  'Do you prefer Apple or Google maps?',
#  'Do you prefer apple juice or orange juice?',
#  'Do you prefer basketball or football?',
#  'Do you prefer the beach or mountains?',
#  'Is your UIN an even number?',
#  'Were you born before or after 2006?',
#  "Would you sit behind the driver or the passenger seat when you're at the back seat in a car?",
#  'Did you come from a big or a small high school?',
#  "Are you shorter or taller than 5'7 (170cm)?",
#  'Do you prefer breakfast or dinner?',
#  'Do you prefer go to school by bus or by walking?',
#  'Did the chicken or the egg come first?',
#  'Do you prefer Coca Cola or Pepsi?',
#  'Do you prefer Coca-Cola or Sprite?',
#  'Do you prefer coffee or tea?',
#  'Dawn or Dusk?',
#  'Would you rather drown or burn to death?',
#  'Are you an extrovert or introvert?',
#  'Do you prefer gold or silver jewelry?',
#  'Do you prefer group projects or solo assignments?',
#  'Do you prefer a hot location vacation or a cold vacation location?',
#  'Do you prefer hotdogs or hamburgers?',
#  'Are you taking stat107 for your major or not?',
#  'Who is a better poet?',
#  "Do you prefer 'light mode' or 'dark mode' on your technological devices?",
#  'Do you have long hair or short hair?',
#  'Do you prefer morning or afternoon classes?',
#  'Do you prefer indoor or outdoor activities?',
#  'Do you prefer Pizza or Cheeseburgers?',
#  'Do you like Messi or Ronaldo?',
#  'Do you prefer running or walking?',
#  'What soccer team is better?',
#  'Do you prefer strawberries or blueberries?',
#  'Do you live in student housing (i.e. dorms) or private housing (i.e. apartments)?',
#  'Do you like the warm or cold weather better?',
#  'Would you rather your head be the size of a watermelon or an orange?',
#  'Do you prefer wings or burgers?',
#  'Do you prefer Playstation or Xbox?',
#  'Y or N?',
#  'Do you like the color yellow?',
#  'Do you like ranch?',
#  'Were you born in the United States?',
#  'Do you consider yourself an international student?',
#  'Have you ever been outside of United States?',
#  'Have you ever had COVID-19?',
#  'Do you like chocolate?',
#  'Do you like spicy food?',
#  'What\'s the color of "the dress"? (See it here: https://en.wikipedia.org/wiki/The_dress)',
#  'Are you taking 16 or more credit hours this semester?',
#  'Do you have siblings?',
#  'Did you play sports in high school? ',
#  'Does pineapple belong on pizza?',
#  'Is purple your favorite color? ',
#  'Do you like bananas?',
#  'Do you like Champaign?',
#  'Do you like rainy weather?',
#  'Does the First Letter of your last name Start with a Letter A-L Including L? ',
#  'Do you like Durian?',
#  'Pick between TRUE or FALSE.',
#  'Do you prefer watching basketball or football games?',
#  'Do you prefer caramel or sprinkle toppings on your ice cream?',
#  'Can you swim? ',
#  'Would you rather be to see the future or change the past?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking?',
#  'How many hours do you sleep in a night?',
#  'How many siblings do you have?',
#  'Pick a number between 1 and 10. ',
#  'What is your shoe size (US size)?',
#  'How many cups (8 oz.) of water do you drink a day?',
#  'What number do you consider as an unlucky number?',
#  'How many people is the ideal number of people at a party?',
#  'What is your phone battery percentage currently at?',
#  'Besides the US, what country would you like to live in?',
#  'What is your favorite color?',
#  'Favorite way to spend your free time?',
#  'What genre of music do you like the most?',
#  'If you were an animal, which would you be? / What is your spirit animal?',
#  'What do you think is the hardest major at UIUC?',
#  'Who is your favorite music artist?',
#  "What's your favorite social media app?",
#  'What is your favorite game to play (either video game or IRL)?',
#  'Where is your dream vacation spot?']

# %% [markdown]
# ## Record the Variable for Your Question
#
# In the cell below, record your binary question's column name as a **string** variable named `analysis_column`.  You'll need that exact column name to reference data from that cell.

# %%
analysis_column =  "Do you prefer sweet or savory food?"
analysis_column
# Out:
# 'Do you prefer sweet or savory food?'

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df' in vars()), "You do not have a DataFrame called `df`."
assert(len(df) >= 1053), "You have not loaded the correct Hello Dataset."
assert(analysis_column in df), "Make certain your analysis_column string is EXACTLY as it appears in the Hello Dataset."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Column Subset: View Only Your Question's Responses
#
# To begin your question's analysis, you first want to **focus only on your question**.  In lecture, we have primarily focused on creating subsets of rows. However, you can also create a subset of columns!
#
# To create a DataFrame with just a single column, you can use the syntax:
# ```
# df[ ["column name"] ]
# ```
# - Notice the **double set of square brackets**.  You need the outer set for `df`, and the inner set for the column name.
# - Because we've already loaded your question into `analysis_column`, you won't need the quotation marks this time.
# - You can find this syntax under the "Subset Variables (Columns)" on your Pandas cheat sheet!
#
# With the `analysis_column` variable from above, use Python to display only the column you're analyzing.  This will make it easy to see what the two options were for your question:

# %%
df[[analysis_column]]
# Out:
#      Do you prefer sweet or savory food?
# 0                            Savory Food
# 1                            Savory Food
# 2                            Savory Food
# 3                             Sweet Food
# 4                            Savory Food
# ...                                  ...
# 1065                          Sweet Food
# 1066                          Sweet Food
# 1067                         Savory Food
# 1068                          Sweet Food
# 1069                          Sweet Food
#
# [1070 rows x 1 columns]

# %% [markdown]
# ## DataFrame: Group One
#
# Create a DataFrame, `df1`, that contains everyone who picked the first option of your two answers.  *(Make sure to make this a subset of the original `df`, and not just your one column.)*

# %%
df1 = df[df[analysis_column]=="Sweet Food"]
df1
# Out:
#            Name       Lab When flipping a coin, heads or tails?  \
# 3      TA Tyler       Y07                                 Tails
# 5          Gage       Y10                                 Heads
# 6         Mark        Y04                                 Heads
# 7         Jaden       Y34                                 Heads
# 9        Amanda       Y23                                 Heads
# ...         ...       ...                                   ...
# 1061  TA Kunlun  Y12, Y25                                 Heads
# 1065   Man Geun       Y04                                 Heads
# 1066   CA Elise  Y11, Y33                                 Heads
# 1068      Bowen       Y25                                 Heads
# 1069   kaicheng       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 3                      Not First Year
# 5                  First Year at UIUC
# 6                      Not First Year
# 7                  First Year at UIUC
# 9                  First Year at UIUC
# ...                               ...
# 1061               First Year at UIUC
# 1065                   Not First Year
# 1066                   Not First Year
# 1068               First Year at UIUC
# 1069               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 3                                             Chocolate
# 5                                               Vanilla
# 6                                             Chocolate
# 7                                             Chocolate
# 9                                               Vanilla
# ...                                                 ...
# 1061                                          Chocolate
# 1065                                            Vanilla
# 1066                                            Vanilla
# 1068                                          Chocolate
# 1069                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 3                             Night                               Even
# 5                             Night                               Even
# 6                           Morning                               Even
# 7                           Morning                               Even
# 9                             Night                               Even
# ...                             ...                                ...
# 1061                        Morning                               Even
# 1065                          Night                               Even
# 1066                          Night                               Even
# 1068                          Night                                Odd
# 1069                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 3                    No                          Winter
# 5                   Yes                          Winter
# 6                    No                          Winter
# 7                    No                          Summer
# 9                   Yes                          Summer
# ...                 ...                             ...
# 1061                Yes                          Summer
# 1065                 No                          Winter
# 1066                Yes                          Summer
# 1068                 No                          Summer
# 1069                 No                          Winter
#
#      Are you a business major?  ...  \
# 3                           No  ...
# 5                           No  ...
# 6                           No  ...
# 7                           No  ...
# 9                          Yes  ...
# ...                        ...  ...
# 1061                        No  ...
# 1065                        No  ...
# 1066                        No  ...
# 1068                        No  ...
# 1069                       Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 3                                                Canada
# 5                                               Canada
# 6                                                Sweden
# 7                                                 japan
# 9                                                   NaN
# ...                                                 ...
# 1061                                              China
# 1065                                              Korea
# 1066                                            England
# 1068                                              China
# 1069                                              china
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 3                          Orange                              Terraria
# 5                           Green                   Fishing or Hunting
# 6                           green                               reading
# 7                            blue                     talk with friends
# 9                           Green                     Watching TV shows
# ...                           ...                                   ...
# 1061                         blue                                  game
# 1065                         Blue                           Playstation
# 1066                         Pink                          With friends
# 1068                       Purple                                 Films
# 1069                         blue                                 sleep
#
#      What genre of music do you like the most?  \
# 3                                     Pop rock
# 5                                 Grunge Rock
# 6                                          pop
# 7                                          pop
# 9                                          Pop
# ...                                        ...
# 1061                                      jazz
# 1065                                       Pop
# 1066                                 Indie pop
# 1068                                      Rocj
# 1069                                     R n B
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 3                                                   Bee
# 5                                                 Bear
# 6                                                 Zebra
# 7                                                   dog
# 9                                               Dolphin
# ...                                                 ...
# 1061                                               egal
# 1065                                                Dog
# 1066                                               Wolf
# 1068                                              Puppy
# 1069                                                dog
#
#      What do you think is the hardest major at UIUC?  \
# 3                               Chemical Engineering
# 5                                              Math
# 6                               computer engineering
# 7                                                 CS
# 9                                        Engineering
# ...                                              ...
# 1061                                              cs
# 1065                                              CS
# 1066                                            Eecs
# 1068                                     Engineering
# 1069                                              ds
#
#      Who is your favorite music artist?  \
# 3                            Billy Joel
# 5                            Jim Croce
# 6                                   sza
# 7                                 keshi
# 9                                   NaN
# ...                                 ...
# 1061                           Coldplay
# 1065                                 IU
# 1066                       Taylor swift
# 1068                         Kanye West
# 1069                           lil tjay
#
#      What's your favorite social media app?  \
# 3                                    Reddit
# 5                                    Tiktok
# 6                                 instagram
# 7                                    wechat
# 9                                 Instagram
# ...                                     ...
# 1061                                 Wechat
# 1065                              Instagram
# 1066                              Pinterest
# 1068                                    ins
# 1069                               snapchat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 3                                              Terraria
# 5                                           Titanfall 2
# 6                                              Fortnite
# 7                                                   LOL
# 9                                                   NaN
# ...                                                 ...
# 1061                                          overwatch
# 1065                                              NBA2k
# 1066                                           Pinochle
# 1068                                     Stardew Valley
# 1069                                                mma
#
#      Where is your dream vacation spot?
# 3                          My apartment
# 5                 Denali National Park
# 6                             australia
# 7                                 china
# 9                                 Italy
# ...                                 ...
# 1061                                 CA
# 1065                             Cancun
# 1066                              Kenya
# 1068                              Tokyo
# 1069                            iceland
#
# [415 rows x 150 columns]

# %% [markdown]
# ## DataFrame: Group Two
#
# Create a new DataFrame, `df2`, that contains everyone who picked the other answer:

# %%
df2 = df[df[analysis_column]=="Savory Food"]
df2
# Out:
#              Name       Lab When flipping a coin, heads or tails?  \
# 0     Prof. Karle  AL1, AL2                                 Heads
# 1      Prof. Wade  AL1, AL2                                 Tails
# 2        Angelina       Y13                                 Tails
# 4          Sneha        Y17                                 Tails
# 8            Eman       Y11                                 Heads
# ...           ...       ...                                   ...
# 1060     TA Jimmy       Y21                                 Tails
# 1062       Eunice       Y28                                 Heads
# 1063        Shlok       Y04                                 Heads
# 1064       Wesley       Y02                                 Tails
# 1067      Chinmay       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 0                      Not First Year
# 1                      Not First Year
# 2                  First Year at UIUC
# 4                  First Year at UIUC
# 8                  First Year at UIUC
# ...                               ...
# 1060               First Year at UIUC
# 1062               First Year at UIUC
# 1063               First Year at UIUC
# 1064                   Not First Year
# 1067               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 0                                             Chocolate
# 1                                               Vanilla
# 2                                               Vanilla
# 4                                               Vanilla
# 8                                             Chocolate
# ...                                                 ...
# 1060                                          Chocolate
# 1062                                          Chocolate
# 1063                                          Chocolate
# 1064                                            Vanilla
# 1067                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 0                             Night                               Even
# 1                             Night                                Odd
# 2                           Morning                               Even
# 4                             Night                               Even
# 8                           Morning                               Even
# ...                             ...                                ...
# 1060                          Night                               Even
# 1062                          Night                               Even
# 1063                          Night                               Even
# 1064                          Night                               Even
# 1067                          Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 0                    No                          Summer
# 1                   Yes                          Winter
# 2                   Yes                          Summer
# 4                    No                          Summer
# 8                    No                          Summer
# ...                 ...                             ...
# 1060                 No                          Summer
# 1062                 No                          Summer
# 1063                 No                          Summer
# 1064                 No                          Summer
# 1067                 No                          Summer
#
#      Are you a business major?  ...  \
# 0                           No  ...
# 1                           No  ...
# 2                           No  ...
# 4                          Yes  ...
# 8                           No  ...
# ...                        ...  ...
# 1060                        No  ...
# 1062                       Yes  ...
# 1063                        No  ...
# 1064                        No  ...
# 1067                        No  ...
#
#      Besides the US, what country would you like to live in?  \
# 0                                          The Maldives
# 1                                                Sweden
# 2                                            Hong Kong
# 4                                                Canada
# 8                                                   UAE
# ...                                                 ...
# 1060                                                 UK
# 1062                                        south korea
# 1063                                             Monaco
# 1064                                              japan
# 1067                                              India
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 0                            pink                         water skiing!
# 1                          Purple                           Programming
# 2                            Pink                        Watching shows
# 4                           Green                 Reading or crocheting
# 8                             Red                Hang out with friends
# ...                           ...                                   ...
# 1060                        Black                        Watching shows
# 1062                         blue                         playing piano
# 1063                        Black                    Listening to music
# 1064                         blue                                 sleep
# 1067                         Blue                                 Music
#
#      What genre of music do you like the most?  \
# 0                                          pop
# 1                                          Pop
# 2                                          r&b
# 4                                     Pop Rock
# 8                                          R&B
# ...                                        ...
# 1060                                       Pop
# 1062                                      kpop
# 1063                                   Hip Hop
# 1064                                       pop
# 1067                                       Rap
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 0                                                 sloth
# 1                                                   Fox
# 2                                                 Tiger
# 4                                               Penguin
# 8                                               Unicorn
# ...                                                 ...
# 1060                                              Panda
# 1062                                              sloth
# 1063                                                Dog
# 1064                                         dog/ camel
# 1067                                                Dog
#
#      What do you think is the hardest major at UIUC?  \
# 0                                   Computer Science
# 1                                   Computer Science
# 2                             Aerospace engineering
# 4                                   Computer Science
# 8                                            Physics
# ...                                              ...
# 1060                                         Physics
# 1062                                     engineering
# 1063                            Computer Engineering
# 1064                                         english
# 1067                                Computer Science
#
#      Who is your favorite music artist?  \
# 0                          Taylor Swift
# 1                          Taylor Swift
# 2                         Ashley Alisha
# 4                       Imagine Dragons
# 8                                   SZA
# ...                                 ...
# 1060                         Kanye West
# 1062                                IVE
# 1063                         Kanye West
# 1064                         juice wrld
# 1067                       Travis Scott
#
#      What's your favorite social media app?  \
# 0                                 Instagram
# 1                                   YouTube
# 2                                     Insta
# 4                                 Instagram
# 8                                 Instagram
# ...                                     ...
# 1060                                Discord
# 1062                              instagram
# 1063                              Instagram
# 1064                                youtube
# 1067                              Instagram
#
#      What is your favorite game to play (either video game or IRL)?  \
# 0                                            volleyball
# 1                                              Factorio
# 2                                                   NaN
# 4                                            Beat Saber
# 8                                                  Sims
# ...                                                 ...
# 1060                                              Poker
# 1062                                            genshin
# 1063                                              Chess
# 1064                                        brawl stars
# 1067                                             Tennis
#
#      Where is your dream vacation spot?
# 0                          The Maldives
# 1                                Acadia
# 2                       Southern France
# 4                                 Italy
# 8                               Greece
# ...                                 ...
# 1060                              Japan
# 1062                              Italy
# 1063                              Spain
# 1064                              japan
# 1067                             Monaco
#
# [652 rows x 150 columns]

# %% [markdown]
# ## Analysis
#
# Discuss the following questions with your group and then write down your response!

# %% [markdown]
# **Q1: What percentage of people chose each of your two binary options?**

# %% [markdown]
# 61% of people preferred Savory Food, while about 39% of people preferred Sweet Food.

# %% [markdown]
# **Q2: Did this surprise you? Why or why not? Write at least one complete sentence.**

# %% [markdown]
# It surprises me a little because I thought it would be split more evenly.

# %% [markdown]
# **Q3: Do you think your question was the closest to a perfect 50/50 split among the whole class?**

# %% [markdown]
# No, I think the numbers learned pretty heavily towards savory food.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 2: Creating Treatment and Control Groups
#
# For the rest of this lab, we will consider the "Hello Dataset" to be a pre-survey of randomly selected participants for an upcoming experiment.  In lecture, you learned that a good experiment will split the participants into two groups: the "treatment" group and the "control" group.
#
# Recall that it is necessary to have both groups:
#
# - The "control" group is a comparison group that will receive a placebo and will act as a control to ensure that the treatment has an effect.
# - The "treatment" group will receive a treatment and we will look for differences between the results of this treatment group and the control group.

# %% [markdown]
# ## Part 2.1: Select a Treatment Group
#
# **Randomly** select half (50%) of the participants from our original `df` to be in the treatment group and place them into a DataFrame called `treatment`.
# - Remember, you can ask your CAs, TAs, or use your **pandas cheat sheet** to help you out!

# %%
treatment = df.sample(frac = 0.5)
treatment
# Out:
#            Name  Lab When flipping a coin, heads or tails?  \
# 989       Ruoyu  Y07                                 Heads
# 219     Praveen  Y32                                 Heads
# 146      Edward  Y08                                 Heads
# 389     Cynthia  Y11                                 Tails
# 380     Celina   Y20                                 Heads
# ..          ...  ...                                   ...
# 978         Ian  Y15                                 Tails
# 936       Aditi  Y29                                 Heads
# 637        Koey  Y17                                 Heads
# 296     Eunice   Y23                                 Heads
# 982  Almuatasim  Y10                                 Heads
#
#     Is this your first year at UIUC?  \
# 989               First Year at UIUC
# 219                   Not First Year
# 146                   Not First Year
# 389               First Year at UIUC
# 380               First Year at UIUC
# ..                               ...
# 978               First Year at UIUC
# 936               First Year at UIUC
# 637               First Year at UIUC
# 296               First Year at UIUC
# 982                   Not First Year
#
#     Is your favorite ice cream flavor chocolate or vanilla?  \
# 989                                            Vanilla
# 219                                            Vanilla
# 146                                            Vanilla
# 389                                            Vanilla
# 380                                          Chocolate
# ..                                                 ...
# 978                                            Vanilla
# 936                                            Vanilla
# 637                                            Vanilla
# 296                                            Vanilla
# 982                                            Vanilla
#
#     Do you like morning or night?  Do you prefer even or odd numbers?  \
# 989                          Night                               Even
# 219                          Night                               Even
# 146                          Night                               Even
# 389                        Morning                                Odd
# 380                          Night                               Even
# ..                             ...                                ...
# 978                          Night                               Even
# 936                        Morning                               Even
# 637                          Night                               Even
# 296                          Night                               Even
# 982                        Morning                                Odd
#
#     Do you have a pet? Do you prefer summer or winter?  \
# 989                Yes                          Summer
# 219                 No                          Summer
# 146                 No                          Winter
# 389                 No                          Summer
# 380                 No                          Summer
# ..                 ...                             ...
# 978                Yes                          Winter
# 936                 No                          Summer
# 637                Yes                          Summer
# 296                 No                          Summer
# 982                 No                          Summer
#
#     Are you a business major?  ...  \
# 989                       Yes  ...
# 219                        No  ...
# 146                        No  ...
# 389                        No  ...
# 380                       Yes  ...
# ..                        ...  ...
# 978                       Yes  ...
# 936                       Yes  ...
# 637                        No  ...
# 296                       Yes  ...
# 982                        No  ...
#
#     Besides the US, what country would you like to live in?  \
# 989                                              China
# 219                                              India
# 146                                          Singapore
# 389                                            Germany
# 380                                        New Zealand
# ..                                                 ...
# 978                                            Ireland
# 936                                         Australia
# 637                                              Japan
# 296                                              Kenya
# 982                                              Qatar
#
#     What is your favorite color? Favorite way to spend your free time?  \
# 989                        Green                              Sleeping
# 219                        Green                          With friends
# 146                        Black                   Reading stockcharts
# 389                        white                       walking ourdoor
# 380                         blue                               Netflix
# ..                           ...                                   ...
# 978                        Green                  Hangout with friends
# 936                         blue       To hang with friends and family
# 637                        Green                           Read novels
# 296                         Pink                     Tiktok scrolling
# 982                        Green                           cod zombies
#
#     What genre of music do you like the most?  \
# 989                                   popular
# 219                                       Rap
# 146                                       Pop
# 389                                       R&B
# 380                                     J-pop
# ..                                        ...
# 978                                       Rap
# 936                                       pop
# 637                                       pop
# 296                                       R&B
# 982                                      none
#
#     If you were an animal, which would you be? / What is your spirit animal?  \
# 989                                               bird
# 219                                              Eagle
# 146                                              Eagle
# 389                                                dog
# 380                                                fox
# ..                                                 ...
# 978                                               Wolf
# 936                                           elephant
# 637                                                Cat
# 296                                              Zebra
# 982                                                NaN
#
#     What do you think is the hardest major at UIUC?  \
# 989                                    Data Science
# 219                                             ECE
# 146                            Chemical Engineering
# 389                                              cs
# 380                                              CS
# ..                                              ...
# 978                                  Civil Engineer
# 936                                computer science
# 637                                              CS
# 296                                Computer Science
# 982                computer electerical engineering
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 989                       Taylor Swift                                 TikTok
# 219                         Tory Lanez                                Youtube
# 146                               Bach                                    NaN
# 389                        Celine Dion                                 wechat
# 380                        back number                              instagram
# ..                                 ...                                    ...
# 978                 Tyler, the Creator                              Instagram
# 936                         zach bryan                                 TikTok
# 637                      Yuuri (j-pop)                                YouTube
# 296                              Lucki                             Instagram
# 982                                NaN                                    NaN
#
#     What is your favorite game to play (either video game or IRL)?  \
# 989                                      Airplane chef
# 219                                              Catch
# 146                                          Minecraft
# 389                                                NaN
# 380                                          Minecraft
# ..                                                 ...
# 978                                         Basketball
# 936                                                Uno
# 637                                     Colorful Stage
# 296                                     Subway Surfers
# 982                                        Cod zombies
#
#     Where is your dream vacation spot?
# 989                               Home
# 219                             Hawaii
# 146                                NaN
# 389                             Greece
# 380                              Italy
# ..                                 ...
# 978                              Japan
# 936                              italy
# 637                  Anywhere in Japan
# 296                              Kenya
# 982                          mountains
#
# [535 rows x 150 columns]

# %% [markdown]
# ## Part 2.2: Select a Control Group
#
# Using the **exact same technique and syntax** as you did above, also randomly select half (50%) of the participants to be in the control group.  Place them into a DataFrame called `control`. For now, it's okay if there are people who are in both groups.

# %%
control = df.sample(frac=0.5)
control
# Out:
#             Name       Lab When flipping a coin, heads or tails?  \
# 72    CA Sangjun       Y08                                 Heads
# 77        Shivam       Y09                                 Heads
# 537         Zach       Y18                                 Tails
# 172        shrut       Y19                                 Heads
# 257        Hazel       Y22                                 Tails
# ...          ...       ...                                   ...
# 716         Noah       Y33                                 Tails
# 926       Jayvyn       Y03                                 Heads
# 1066    CA Elise  Y11, Y33                                 Heads
# 1007      Samuel       Y13                                 Heads
# 555       Alyssa       Y23                                 Tails
#
#      Is this your first year at UIUC?  \
# 72                     Not First Year
# 77                 First Year at UIUC
# 537                First Year at UIUC
# 172                    Not First Year
# 257                First Year at UIUC
# ...                               ...
# 716                    Not First Year
# 926                    Not First Year
# 1066                   Not First Year
# 1007               First Year at UIUC
# 555                First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 72                                              Vanilla
# 77                                            Chocolate
# 537                                             Vanilla
# 172                                           Chocolate
# 257                                             Vanilla
# ...                                                 ...
# 716                                             Vanilla
# 926                                             Vanilla
# 1066                                            Vanilla
# 1007                                            Vanilla
# 555                                           Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 72                            Night                               Even
# 77                            Night                               Even
# 537                           Night                                Odd
# 172                         Morning                               Even
# 257                           Night                                Odd
# ...                             ...                                ...
# 716                           Night                               Even
# 926                           Night                                Odd
# 1066                          Night                               Even
# 1007                          Night                               Even
# 555                         Morning                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 72                   No                          Winter
# 77                   No                          Summer
# 537                 Yes                          Summer
# 172                  No                          Winter
# 257                  No                          Summer
# ...                 ...                             ...
# 716                 Yes                          Winter
# 926                 Yes                          Winter
# 1066                Yes                          Summer
# 1007                Yes                          Summer
# 555                  No                          Summer
#
#      Are you a business major?  ...  \
# 72                          No  ...
# 77                          No  ...
# 537                        Yes  ...
# 172                         No  ...
# 257                         No  ...
# ...                        ...  ...
# 716                         No  ...
# 926                         No  ...
# 1066                        No  ...
# 1007                        No  ...
# 555                        Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 72                                                Korea
# 77                                           Australia
# 537                                              Canada
# 172                                         Switzerland
# 257              Japan, Germany, Singapore, Mexico City
# ...                                                 ...
# 716                                              Canada
# 926                                              Canada
# 1066                                            England
# 1007                                            germany
# 555                                               Italy
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 72                          Green                                 Games
# 77                           Blue                          With friends
# 537                         Green              hanging out with friends
# 172                        Purple                          With friends
# 257                          Blue                           Video games
# ...                           ...                                   ...
# 716                         Green                    listening to music
# 926                          Pink                                Gaming
# 1066                         Pink                          With friends
# 1007                       purple                              Relaxing
# 555                        Purple              Hanging out with friends
#
#      What genre of music do you like the most?  \
# 72                                   Reggaeton
# 77                                         Rap
# 537                                        rap
# 172                                      R & B
# 257                                      J-pop
# ...                                        ...
# 716                                        rap
# 926                                        pop
# 1066                                 Indie pop
# 1007                                       rap
# 555                                        Pop
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 72                                                  Cat
# 77                                                Tiger
# 537                                                 dog
# 172                                             Cheetah
# 257                                            antelope
# ...                                                 ...
# 716                                                Wolf
# 926                                         Ball Python
# 1066                                               Wolf
# 1007                                              sloth
# 555                                             Dolphin
#
#      What do you think is the hardest major at UIUC?  \
# 72                                       Engineering
# 77                                 Computer Science
# 537                             computer engineering
# 172                                 Nuclear Sciences
# 257                                     Neuroscience
# ...                                              ...
# 716                             Computer Engineering
# 926                                 Computer Science
# 1066                                            Eecs
# 1007                                Computer science
# 555                                      Engineering
#
#      Who is your favorite music artist?  \
# 72                            Bad bunny
# 77                          Tory Lanez
# 537                               Drake
# 172                        Travis Scott
# 257                           Fuji Kaze
# ...                                 ...
# 716                      kendrick lamar
# 926                          Conan Gray
# 1066                       Taylor swift
# 1007                              Lucki
# 555                       Morgan Wallen
#
#      What's your favorite social media app?  \
# 72                                   Tiktok
# 77                                Instagram
# 537                               instagram
# 172                               Instagram
# 257                               Instagram
# ...                                     ...
# 716                                  tiktok
# 926                                  Tiktok
# 1066                              Pinterest
# 1007                              Instagram
# 555                                 Tik Tok
#
#      What is your favorite game to play (either video game or IRL)?  \
# 72                                             Fortnite
# 77                                  College Football 25
# 537                                              ncaa25
# 172                                          Basketball
# 257                                   Exploding Kittens
# ...                                                 ...
# 716                                            football
# 926                                      Cyberpunk 2077
# 1066                                           Pinochle
# 1007                                   Grand theft auto
# 555                                         Candy Crush
#
#      Where is your dream vacation spot?
# 72                          Switzerland
# 77                         New Zealand
# 537                           bora bora
# 172                             Bahamas
# 257                               Japan
# ...                                 ...
# 716                               Japan
# 926                              Berlin
# 1066                              Kenya
# 1007                            bahamas
# 555                               Italy
#
# [535 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( len(treatment) == len(control) ), "The `treatment` and `control` groups must be the same size."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`."
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Overlapping Selection?
#
# The following code will detect rows that are **both in your treatment and control** groups.
#
# Run the following cell to see everyone who is in both groups:

# %%
df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]
# Out:
#             Name          Lab When flipping a coin, heads or tails?  \
# 1     Prof. Wade     AL1, AL2                                 Tails
# 4         Sneha           Y17                                 Tails
# 5           Gage          Y10                                 Heads
# 6          Mark           Y04                                 Heads
# 8           Eman          Y11                                 Heads
# ...          ...          ...                                   ...
# 1050      Rohail          Y15                                 Tails
# 1052     CA Soph  Y05 Y07 Y14                                 Heads
# 1057    CA Bella          Y34                                 Heads
# 1065    Man Geun          Y04                                 Heads
# 1066    CA Elise     Y11, Y33                                 Heads
#
#      Is this your first year at UIUC?  \
# 1                      Not First Year
# 4                  First Year at UIUC
# 5                  First Year at UIUC
# 6                      Not First Year
# 8                  First Year at UIUC
# ...                               ...
# 1050               First Year at UIUC
# 1052                   Not First Year
# 1057                   Not First Year
# 1065                   Not First Year
# 1066                   Not First Year
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 1                                               Vanilla
# 4                                               Vanilla
# 5                                               Vanilla
# 6                                             Chocolate
# 8                                             Chocolate
# ...                                                 ...
# 1050                                            Vanilla
# 1052                                          Chocolate
# 1057                                          Chocolate
# 1065                                            Vanilla
# 1066                                            Vanilla
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 1                             Night                                Odd
# 4                             Night                               Even
# 5                             Night                               Even
# 6                           Morning                               Even
# 8                           Morning                               Even
# ...                             ...                                ...
# 1050                          Night                               Even
# 1052                          Night                               Even
# 1057                        Morning                               Even
# 1065                          Night                               Even
# 1066                          Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 1                   Yes                          Winter
# 4                    No                          Summer
# 5                   Yes                          Winter
# 6                    No                          Winter
# 8                    No                          Summer
# ...                 ...                             ...
# 1050                 No                          Summer
# 1052                Yes                          Winter
# 1057                Yes                          Summer
# 1065                 No                          Winter
# 1066                Yes                          Summer
#
#      Are you a business major?  ...  \
# 1                           No  ...
# 4                          Yes  ...
# 5                           No  ...
# 6                           No  ...
# 8                           No  ...
# ...                        ...  ...
# 1050                       Yes  ...
# 1052                        No  ...
# 1057                        No  ...
# 1065                        No  ...
# 1066                        No  ...
#
#      Besides the US, what country would you like to live in?  \
# 1                                                Sweden
# 4                                                Canada
# 5                                               Canada
# 6                                                Sweden
# 8                                                   UAE
# ...                                                 ...
# 1050                                              Dubai
# 1052                                            Finland
# 1057                                            sweeden
# 1065                                              Korea
# 1066                                            England
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 1                          Purple                           Programming
# 4                           Green                 Reading or crocheting
# 5                           Green                   Fishing or Hunting
# 6                           green                               reading
# 8                             Red                Hang out with friends
# ...                           ...                                   ...
# 1050                         Pink                                  Read
# 1052                          Red                          With friends
# 1057                       purple                               outside
# 1065                         Blue                           Playstation
# 1066                         Pink                          With friends
#
#      What genre of music do you like the most?  \
# 1                                          Pop
# 4                                     Pop Rock
# 5                                 Grunge Rock
# 6                                          pop
# 8                                          R&B
# ...                                        ...
# 1050                                       R&B
# 1052                                     Indie
# 1057                                       pop
# 1065                                       Pop
# 1066                                 Indie pop
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 1                                                   Fox
# 4                                               Penguin
# 5                                                 Bear
# 6                                                 Zebra
# 8                                               Unicorn
# ...                                                 ...
# 1050                                             Monkey
# 1052                                              Shark
# 1057                                          butterfly
# 1065                                                Dog
# 1066                                               Wolf
#
#      What do you think is the hardest major at UIUC?  \
# 1                                   Computer Science
# 4                                   Computer Science
# 5                                              Math
# 6                               computer engineering
# 8                                            Physics
# ...                                              ...
# 1050                                         CS+Math
# 1052                             Bioengineering + CS
# 1057                            chemical engineering
# 1065                                              CS
# 1066                                            Eecs
#
#      Who is your favorite music artist?  \
# 1                          Taylor Swift
# 4                       Imagine Dragons
# 5                            Jim Croce
# 6                                   sza
# 8                                   SZA
# ...                                 ...
# 1050                      Playboi Carti
# 1052                                BTS
# 1057                       taylor swift
# 1065                                 IU
# 1066                       Taylor swift
#
#      What's your favorite social media app?  \
# 1                                   YouTube
# 4                                 Instagram
# 5                                    Tiktok
# 6                                 instagram
# 8                                 Instagram
# ...                                     ...
# 1050                              Instagram
# 1052                                 TikTok
# 1057                              pinterest
# 1065                              Instagram
# 1066                              Pinterest
#
#      What is your favorite game to play (either video game or IRL)?  \
# 1                                              Factorio
# 4                                            Beat Saber
# 5                                           Titanfall 2
# 6                                              Fortnite
# 8                                                  Sims
# ...                                                 ...
# 1050                                           Fortnite
# 1052                                          Minecraft
# 1057                             pretty pretty princess
# 1065                                              NBA2k
# 1066                                           Pinochle
#
#      Where is your dream vacation spot?
# 1                                Acadia
# 4                                 Italy
# 5                 Denali National Park
# 6                             australia
# 8                               Greece
# ...                                 ...
# 1050                   Santorini Greece
# 1052                            Croatia
# 1057                             vienna
# 1065                             Cancun
# 1066                              Kenya
#
# [270 rows x 150 columns]

# %% [markdown]
# **Q4: Why would your code result in some people being included in both groups? Write at least one complete sentence explaining why you think this might occur.**

# %% [markdown]
# It randomly selects half of all people. Since it's a random selection, it chooses half of people at random, regardless if they were randomly chosen in the previous line of code.

# %% [markdown]
# ## Part 2.3:
#
# Read the following guide on **using `.index.isin` to select all rows from a DataFrame not in another DataFrame**: https://discovery.cs.illinois.edu/guides/DataFrame-Row-Selection/dataframe-isin-selection/
#
# Finally, create a new `control` group that contains all of the participants from `df` that are not in `treatment`:

# %%
control =  df[ ~df.index.isin(treatment.index) ]
control
# Out:
#              Name       Lab When flipping a coin, heads or tails?  \
# 0     Prof. Karle  AL1, AL2                                 Heads
# 9          Amanda       Y23                                 Heads
# 10      Stephanie       Y36                                 Heads
# 13       Kristina       Y33                                 Tails
# 14         Smaya        Y30                                 Tails
# ...           ...       ...                                   ...
# 1062       Eunice       Y28                                 Heads
# 1063        Shlok       Y04                                 Heads
# 1064       Wesley       Y02                                 Tails
# 1067      Chinmay       Y11                                 Heads
# 1069     kaicheng       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 0                      Not First Year
# 9                  First Year at UIUC
# 10                 First Year at UIUC
# 13                     Not First Year
# 14                 First Year at UIUC
# ...                               ...
# 1062               First Year at UIUC
# 1063               First Year at UIUC
# 1064                   Not First Year
# 1067               First Year at UIUC
# 1069               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 0                                             Chocolate
# 9                                               Vanilla
# 10                                            Chocolate
# 13                                              Vanilla
# 14                                            Chocolate
# ...                                                 ...
# 1062                                          Chocolate
# 1063                                          Chocolate
# 1064                                            Vanilla
# 1067                                          Chocolate
# 1069                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 0                             Night                               Even
# 9                             Night                               Even
# 10                            Night                               Even
# 13                            Night                               Even
# 14                          Morning                                Odd
# ...                             ...                                ...
# 1062                          Night                               Even
# 1063                          Night                               Even
# 1064                          Night                               Even
# 1067                          Night                               Even
# 1069                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 0                    No                          Summer
# 9                   Yes                          Summer
# 10                   No                          Summer
# 13                   No                          Winter
# 14                   No                          Winter
# ...                 ...                             ...
# 1062                 No                          Summer
# 1063                 No                          Summer
# 1064                 No                          Summer
# 1067                 No                          Summer
# 1069                 No                          Winter
#
#      Are you a business major?  ...  \
# 0                           No  ...
# 9                          Yes  ...
# 10                          No  ...
# 13                          No  ...
# 14                          No  ...
# ...                        ...  ...
# 1062                       Yes  ...
# 1063                        No  ...
# 1064                        No  ...
# 1067                        No  ...
# 1069                       Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 0                                          The Maldives
# 9                                                   NaN
# 10                                                Japan
# 13                                             Ireland
# 14                                                Spain
# ...                                                 ...
# 1062                                        south korea
# 1063                                             Monaco
# 1064                                              japan
# 1067                                              India
# 1069                                              china
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 0                            pink                         water skiing!
# 9                           Green                     Watching TV shows
# 10                           pink              hanging out with friends
# 13                     sage green               Hanging with my friends
# 14                         purple                       Listen to music
# ...                           ...                                   ...
# 1062                         blue                         playing piano
# 1063                        Black                    Listening to music
# 1064                         blue                                 sleep
# 1067                         Blue                                 Music
# 1069                         blue                                 sleep
#
#      What genre of music do you like the most?  \
# 0                                          pop
# 9                                          Pop
# 10                                         r&b
# 13                  alternative and indie folk
# 14                                       Indie
# ...                                        ...
# 1062                                      kpop
# 1063                                   Hip Hop
# 1064                                       pop
# 1067                                       Rap
# 1069                                     R n B
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 0                                                 sloth
# 9                                               Dolphin
# 10                                                  cat
# 13                                               kitten
# 14                                               donkey
# ...                                                 ...
# 1062                                              sloth
# 1063                                                Dog
# 1064                                         dog/ camel
# 1067                                                Dog
# 1069                                                dog
#
#      What do you think is the hardest major at UIUC?  \
# 0                                   Computer Science
# 9                                        Engineering
# 10                                  Computer Science
# 13                                           pre-med
# 14                                               ECE
# ...                                              ...
# 1062                                     engineering
# 1063                            Computer Engineering
# 1064                                         english
# 1067                                Computer Science
# 1069                                              ds
#
#      Who is your favorite music artist?  \
# 0                          Taylor Swift
# 9                                   NaN
# 10                                  SZA
# 13                        Joni Mitchell
# 14                               Hozier
# ...                                 ...
# 1062                                IVE
# 1063                         Kanye West
# 1064                         juice wrld
# 1067                       Travis Scott
# 1069                           lil tjay
#
#      What's your favorite social media app?  \
# 0                                 Instagram
# 9                                 Instagram
# 10                                   tiktok
# 13                                instagram
# 14                                Instagram
# ...                                     ...
# 1062                              instagram
# 1063                              Instagram
# 1064                                youtube
# 1067                              Instagram
# 1069                               snapchat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 0                                            volleyball
# 9                                                   NaN
# 10                                          crossy road
# 13                                     Dress to Impress
# 14                                             Celeste
# ...                                                 ...
# 1062                                            genshin
# 1063                                              Chess
# 1064                                        brawl stars
# 1067                                             Tennis
# 1069                                                mma
#
#      Where is your dream vacation spot?
# 0                          The Maldives
# 9                                 Italy
# 10                                Japan
# 13                      South of France
# 14                                Paris
# ...                                 ...
# 1062                              Italy
# 1063                              Spain
# 1064                              japan
# 1067                             Monaco
# 1069                            iceland
#
# [535 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`."
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`."
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 2.4: Finding Yourself!
#
# Use the following cells to write Python code to find yourself in either the treatment group or control group.
# - **Hint**: How do you select a subset of rows?  What conditional will identify you?
# - If you did not fill out the "Hello Survey", then you are not in this dataset. :(
# - If you are not in this survey, find either "Prof. Wade" or "Prof. Karle" instead  *(those are the names we used in the `Name` column).*

# %%
treatment[(treatment["Name"] == "Sara") & (treatment["Lab"] == "Y08")]
# Out:
# Empty DataFrame
# Columns: [Name, Lab, When flipping a coin, heads or tails?, Is this your first year at UIUC?, Is your favorite ice cream flavor chocolate or vanilla?, Do you like morning or night? , Do you prefer even or odd numbers?, Do you have a pet?, Do you prefer summer or winter?, Are you a business major?, Do you prefer Movies or TV shows?, Do you prefer pizza or hamburgers?, Are you male or female?, Do you prefer the color Blue or Red?, Do you like Taylor Swifts music?, Do you prefer sweet or salty food?, Do you eat breakfast in the mornings?, Ice cream or cake? , Are you an upperclassman or an underclassman?, As you walk in from the back, do you prefer to sit on the left or right side of lecture?, Is the day of the month of your birthday an odd or even number?, Do you speak a second language?, Do you prefer cats or dogs?, Are you a morning person or a night person?, Do you enjoy reading?, Do you prefer milk chocolate or dark chocolate?, Do you prefer Italian or Mexican food?, Do you prefer sugar cookies or chocolate chip cookies?, Can you speak a second language fluently?, Do you prefer Math or English?, Do you like apples or bananas?, Waffles or pancakes?, Do you prefer day or night?, Do you prefer lecture halls or small classes? , Are you in-state or out of state?, Do you typically shower in the morning or at night?, Does money buy happiness?, Do you prefer to party or stay in?, McDonalds or Burger King?, Do you prefer sweet or savory food?, What month is your birthday?, Do you drink a cup of coffee every morning?, Do you drink coffee?, Do you use a Mac or Windows Laptop?, Do you prefer brownies or cookies?, Google Docs or Microsoft Word?, Do you like horror movies?, Do you have programming experience?, Do you like pizza or pasta?, Do you wear glasses?, Do you like your dorm?, Fall or spring season?, Do you prefer pink or blue?, Are you from the Chicagoland area?, Does your NetID end with an even or odd number?, Are you wearing something on your wrist currently?, Is it called Futbol or Soccer?, Do you use corrective lenses (contacts/glasses)?, Do you prefer Apple Music or Spotify?, Do you have exactly one sibling?, Are you taking any other computer science classes?, In the DISCOVERY lecture, do you sit in the front 50% or back 50%?, Do you sit on the left or right side in lecture?, Pick a random number 1-10. is the number you picked odd or even?, Are you from Chicago?, Pick a number: One or Two., Do you prefer to study alone or in groups?, Do you prefer Apple or Google maps?, Do you prefer apple juice or orange juice?, Do you prefer basketball or football?, Do you prefer the beach or mountains?, Is your UIN an even number?, Were you born before or after 2006?, Would you sit behind the driver or the passenger seat when you're at the back seat in a car?, Did you come from a big or a small high school?, Are you shorter or taller than 5'7 (170cm)?, Do you prefer breakfast or dinner?, Do you prefer go to school by bus or by walking?, Did the chicken or the egg come first?, Do you prefer Coca Cola or Pepsi?, Do you prefer Coca-Cola or Sprite?, Do you prefer coffee or tea?, Dawn or Dusk?, Would you rather drown or burn to death?, Are you an extrovert or introvert?, Do you prefer gold or silver jewelry?, Do you prefer group projects or solo assignments?, Do you prefer a hot location vacation or a cold vacation location?, Do you prefer hotdogs or hamburgers?, Are you taking stat107 for your major or not?, Who is a better poet?, Do you prefer 'light mode' or 'dark mode' on your technological devices?, Do you have long hair or short hair?, Do you prefer morning or afternoon classes?, Do you prefer indoor or outdoor activities?, Do you prefer Pizza or Cheeseburgers?, Do you like Messi or Ronaldo?, Do you prefer running or walking?, What soccer team is better?, Do you prefer strawberries or blueberries?, ...]
# Index: []
#
# [0 rows x 150 columns]

# %% [markdown]
# ## Analysis: Finding Yourself!
#
# **Q5: Which group where you in -- treatment or control?**

# %% [markdown]
# Treatment group!

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Using Blocking to Create Treatment and Control Groups that are Balanced
#
# In your pre-experiment research, you have reason to believe that how the participants answer **your group's question** might influence the response of this experiment!  Oh no! Even though this is a large sample of participants, we want to block to be absolutely sure that the treatment and control groups are balanced with regard to your group's question!
#
# To control for this, we will using **blocking**!  Remember from lecture that blocking refers to creating subgroups for each response, selecting equal-sized treatment and control groups from each block, and then combining all the treatment groups together and all the control groups together to get the final groups. This ensures that your groups are balanced with regard to the variable you blocked on!
#
# You have already done some of this work:
# - Earlier in this notebook, you created `df1` that includes everyone who answered your group's question one way.
# - Earlier in this notebook, you created `df2` that includes everyone who answered your group's question the other way.

# %% [markdown]
# ## Part 3.1:
#
# Create a `df1_treatment` group that contains a random selection of 50% of the rows from `df1`.

# %%
df1_treatment = df1.sample(frac=0.5)
df1_treatment
# Out:
#             Name       Lab When flipping a coin, heads or tails?  \
# 360         Ryan       Y36                                 Heads
# 593     Nikitha        Y15                                 Heads
# 960     TA Omkar  Y11, Y26                                 Heads
# 964        Jiayi       Y03                                 Heads
# 469   CA Lyndsey       Y08                                 Heads
# ...          ...       ...                                   ...
# 258        Aarya       Y19                                 Heads
# 56         Julia       Y25                                 Heads
# 1044       Panth       Y29                                 Tails
# 1049      Andrew       Y21                                 Heads
# 587         Jeet       Y17                                 Tails
#
#      Is this your first year at UIUC?  \
# 360                First Year at UIUC
# 593                First Year at UIUC
# 960                    Not First Year
# 964                First Year at UIUC
# 469                    Not First Year
# ...                               ...
# 258                First Year at UIUC
# 56                     Not First Year
# 1044               First Year at UIUC
# 1049               First Year at UIUC
# 587                First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 360                                           Chocolate
# 593                                           Chocolate
# 960                                           Chocolate
# 964                                           Chocolate
# 469                                           Chocolate
# ...                                                 ...
# 258                                             Vanilla
# 56                                            Chocolate
# 1044                                            Vanilla
# 1049                                          Chocolate
# 587                                             Vanilla
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 360                           Night                               Even
# 593                         Morning                                Odd
# 960                         Morning                               Even
# 964                           Night                               Even
# 469                         Morning                               Even
# ...                             ...                                ...
# 258                           Night                               Even
# 56                            Night                               Even
# 1044                          Night                               Even
# 1049                        Morning                               Even
# 587                           Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 360                  No                          Summer
# 593                  No                          Summer
# 960                  No                          Summer
# 964                  No                          Summer
# 469                 Yes                          Summer
# ...                 ...                             ...
# 258                 Yes                          Summer
# 56                   No                          Summer
# 1044                Yes                          Summer
# 1049                Yes                          Summer
# 587                  No                          Summer
#
#      Are you a business major?  ...  \
# 360                         No  ...
# 593                         No  ...
# 960                         No  ...
# 964                         No  ...
# 469                         No  ...
# ...                        ...  ...
# 258                        Yes  ...
# 56                          No  ...
# 1044                        No  ...
# 1049                       Yes  ...
# 587                        Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 360                                              Canada
# 593                                               spain
# 960                                               india
# 964                                           Australia
# 469                                               italy
# ...                                                 ...
# 258                                             Sweden
# 56                                                korea
# 1044                                           Scotland
# 1049                                             Greece
# 587                                              Sweden
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 360                          blue                       watching videos
# 593                   blue +green                        sleep and read
# 960                          teal                              sleeping
# 964                          Blue                       watching movies
# 469                           red                              shopping
# ...                           ...                                   ...
# 258                       Purple                                Baking
# 56                        purple                                 sleep
# 1044                         Grey                                 Sleep
# 1049                         Blue                            Basketball
# 587                          blue   Hanging out with friends and family
#
#      What genre of music do you like the most?  \
# 360                                      j pop
# 593                                        pop
# 960                                  bollywood
# 964                                        Pop
# 469                                        pop
# ...                                        ...
# 258                                        Pop
# 56                                      indie
# 1044                                      Rock
# 1049                                   Hip hop
# 587                                        rap
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 360                                                 cat
# 593                                             panther
# 960                                                 NaN
# 964                                                 Cat
# 469                                            shih tzu
# ...                                                 ...
# 258                                               Lion
# 56                                                 deer
# 1044                                              Sloth
# 1049                                            Panther
# 587                                             cheetah
#
#      What do you think is the hardest major at UIUC?  \
# 360                                      Mathematics
# 593                                          physics
# 960                                              ECE
# 964                                               CS
# 469                                 computer science
# ...                                              ...
# 258                                               CS
# 56                                      engineering
# 1044                                              CS
# 1049                                              CS
# 587                                 Computer Science
#
#      Who is your favorite music artist?  \
# 360                              millet
# 593                         don toliver
# 960                        arijit singh
# 964                            Tao, Zhe
# 469                       gracie abrams
# ...                                 ...
# 258                          Billy Joel
# 56                              claire
# 1044                               Mili
# 1049                              Drake
# 587                         Don Toliver
#
#      What's your favorite social media app?  \
# 360                               instagram
# 593                                 tik tok
# 960                               instagram
# 964                                  TikTok
# 469                               instagram
# ...                                     ...
# 258                              Instagram
# 56                                    insta
# 1044                                Discord
# 1049                              Instagram
# 587                                  Tiktok
#
#      What is your favorite game to play (either video game or IRL)?  \
# 360                                           Persona 5
# 593                                              tetris
# 960                                                fifa
# 964                                        It Takes Two
# 469                                          pickleball
# ...                                                 ...
# 258                                           Fortnite
# 56                                                none
# 1044                                 Deep Rock Galactic
# 1049                                      Squad Busters
# 587                                            fortnite
#
#      Where is your dream vacation spot?
# 360                              Hawaii
# 593                          carribeans
# 960                               spain
# 964                               China
# 469                               italy
# ...                                 ...
# 258                           Thailand
# 56                               italy
# 1044                             Greece
# 1049                               Bali
# 587                              Hawaii
#
# [208 rows x 150 columns]

# %% [markdown]
# ## Part 3.2:
#
# Create a `df1_control` group that contains the other half of the rows from `df1`. *(You can refer back to Part 2 to refresh on how to do this, make sure you use `df1` and `df1_control` as your DataFrames.)*

# %%
df1_control =  df1[ ~df1.index.isin(df1_treatment.index) ]
df1_control
# Out:
#            Name       Lab When flipping a coin, heads or tails?  \
# 3      TA Tyler       Y07                                 Tails
# 9        Amanda       Y23                                 Heads
# 16      Aaliyay       Y30                                 Heads
# 17       Albert       Y10                                 Heads
# 18        Colin       Y07                                 Heads
# ...         ...       ...                                   ...
# 1050     Rohail       Y15                                 Tails
# 1054   CA Maddy       Y36                                 Heads
# 1055  CA Anchal  Y31, Y19                                 Heads
# 1057   CA Bella       Y34                                 Heads
# 1069   kaicheng       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 3                      Not First Year
# 9                  First Year at UIUC
# 16                 First Year at UIUC
# 17                 First Year at UIUC
# 18                 First Year at UIUC
# ...                               ...
# 1050               First Year at UIUC
# 1054                   Not First Year
# 1055                   Not First Year
# 1057                   Not First Year
# 1069               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 3                                             Chocolate
# 9                                               Vanilla
# 16                                              Vanilla
# 17                                              Vanilla
# 18                                              Vanilla
# ...                                                 ...
# 1050                                            Vanilla
# 1054                                            Vanilla
# 1055                                            Vanilla
# 1057                                          Chocolate
# 1069                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 3                             Night                               Even
# 9                             Night                               Even
# 16                            Night                               Even
# 17                            Night                                Odd
# 18                            Night                                Odd
# ...                             ...                                ...
# 1050                          Night                               Even
# 1054                        Morning                               Even
# 1055                          Night                                Odd
# 1057                        Morning                               Even
# 1069                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 3                    No                          Winter
# 9                   Yes                          Summer
# 16                  Yes                          Summer
# 17                   No                          Summer
# 18                  Yes                          Summer
# ...                 ...                             ...
# 1050                 No                          Summer
# 1054                 No                          Summer
# 1055                 No                          Winter
# 1057                Yes                          Summer
# 1069                 No                          Winter
#
#      Are you a business major?  ...  \
# 3                           No  ...
# 9                          Yes  ...
# 16                          No  ...
# 17                          No  ...
# 18                         Yes  ...
# ...                        ...  ...
# 1050                       Yes  ...
# 1054                        No  ...
# 1055                        No  ...
# 1057                        No  ...
# 1069                       Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 3                                                Canada
# 9                                                   NaN
# 16                                              Canada
# 17                                               Poland
# 18                                                italy
# ...                                                 ...
# 1050                                              Dubai
# 1054                                             greece
# 1055                                              Spain
# 1057                                            sweeden
# 1069                                              china
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 3                          Orange                              Terraria
# 9                           Green                     Watching TV shows
# 16                           blue                              on phone
# 17                            Red                                Soccer
# 18                     dark green                       watching movies
# ...                           ...                                   ...
# 1050                         Pink                                  Read
# 1054                         pink                           working out
# 1055                         blue                                 sleep
# 1057                       purple                               outside
# 1069                         blue                                 sleep
#
#      What genre of music do you like the most?  \
# 3                                     Pop rock
# 9                                          Pop
# 16                                         rnb
# 17                                         Rap
# 18                                       indie
# ...                                        ...
# 1050                                       R&B
# 1054                                       pop
# 1055                                       Pop
# 1057                                       pop
# 1069                                     R n B
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 3                                                   Bee
# 9                                               Dolphin
# 16                                                 bird
# 17                                                Tiger
# 18                                                  dog
# ...                                                 ...
# 1050                                             Monkey
# 1054                                                cat
# 1055                                              Panda
# 1057                                          butterfly
# 1069                                                dog
#
#      What do you think is the hardest major at UIUC?  \
# 3                               Chemical Engineering
# 9                                        Engineering
# 16                             aerospace engineering
# 17                              Chemical Engineering
# 18                                  computer science
# ...                                              ...
# 1050                                         CS+Math
# 1054                                        comp sci
# 1055                                              CS
# 1057                            chemical engineering
# 1069                                              ds
#
#      Who is your favorite music artist?  \
# 3                            Billy Joel
# 9                                   NaN
# 16                          Frank Ocean
# 17                         Travis Scott
# 18                              wallows
# ...                                 ...
# 1050                      Playboi Carti
# 1054                       taylor swift
# 1055                        The Weekend
# 1057                       taylor swift
# 1069                           lil tjay
#
#      What's your favorite social media app?  \
# 3                                    Reddit
# 9                                 Instagram
# 16                                   tiktok
# 17                                Instagram
# 18                                instagram
# ...                                     ...
# 1050                              Instagram
# 1054                                 tiktok
# 1055                                 TikTok
# 1057                              pinterest
# 1069                               snapchat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 3                                              Terraria
# 9                                                   NaN
# 16                                               sims 4
# 17                                               Soccer
# 18                                           mario kart
# ...                                                 ...
# 1050                                           Fortnite
# 1054                                        super mario
# 1055                                           Snake.io
# 1057                             pretty pretty princess
# 1069                                                mma
#
#      Where is your dream vacation spot?
# 3                          My apartment
# 9                                 Italy
# 16                               eurpoe
# 17                              Croatia
# 18                               hawaii
# ...                                 ...
# 1050                   Santorini Greece
# 1054                             greece
# 1055                            Iceland
# 1057                             vienna
# 1069                            iceland
#
# [207 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df1_treatment' in vars() ), "You do not have a DataFrame called `df1_treatment`."
assert( 'df1_control' in vars() ), "You do not have a DataFrame called `df1_control`."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df1_control.index) ]) == 0), "The `df1_treatment` and `df1_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df2.index) ]) == 0), "The `df1_treatment` and `df2` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_control.index) & df.index.isin(df2.index) ]) == 0), "The `df1_control` and `df2` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.3:
#
# Create a `df2_treatment` group that contains a random selection of 50% of the rows from `df2`.

# %%
df2_treatment = df2.sample(frac=0.5)
df2_treatment
# Out:
#           Name  Lab When flipping a coin, heads or tails?  \
# 928      Cesar  Y05                                 Heads
# 909      Chuck  Y05                                 Heads
# 416       Kush  Y15                                 Heads
# 976    Patrick  Y12                                 Heads
# 243      Chloe  Y09                                 Heads
# ...        ...  ...                                   ...
# 898       Gaby  Y08                                 Tails
# 1060  TA Jimmy  Y21                                 Tails
# 453    Chantal  Y10                                 Heads
# 215     Ashley  Y23                                 Heads
# 58      Olivia  Y30                                 Tails
#
#      Is this your first year at UIUC?  \
# 928                    Not First Year
# 909                First Year at UIUC
# 416                First Year at UIUC
# 976                First Year at UIUC
# 243                    Not First Year
# ...                               ...
# 898                    Not First Year
# 1060               First Year at UIUC
# 453                    Not First Year
# 215                First Year at UIUC
# 58                 First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 928                                             Vanilla
# 909                                           Chocolate
# 416                                           Chocolate
# 976                                           Chocolate
# 243                                           Chocolate
# ...                                                 ...
# 898                                             Vanilla
# 1060                                          Chocolate
# 453                                             Vanilla
# 215                                           Chocolate
# 58                                              Vanilla
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 928                           Night                               Even
# 909                         Morning                               Even
# 416                         Morning                               Even
# 976                         Morning                               Even
# 243                           Night                               Even
# ...                             ...                                ...
# 898                           Night                               Even
# 1060                          Night                               Even
# 453                         Morning                                Odd
# 215                           Night                               Even
# 58                          Morning                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 928                 Yes                          Summer
# 909                 Yes                          Winter
# 416                  No                          Winter
# 976                  No                          Winter
# 243                  No                          Summer
# ...                 ...                             ...
# 898                 Yes                          Winter
# 1060                 No                          Summer
# 453                 Yes                          Winter
# 215                 Yes                          Summer
# 58                  Yes                          Winter
#
#      Are you a business major?  ...  \
# 928                         No  ...
# 909                        Yes  ...
# 416                        Yes  ...
# 976                        Yes  ...
# 243                         No  ...
# ...                        ...  ...
# 898                         No  ...
# 1060                        No  ...
# 453                         No  ...
# 215                         No  ...
# 58                          No  ...
#
#      Besides the US, what country would you like to live in?  \
# 928                                               Spain
# 909                                            England
# 416                                               India
# 976                                               Italy
# 243                                         South Korea
# ...                                                 ...
# 898                                              Mexico
# 1060                                                 UK
# 453                                              Canada
# 215                                               China
# 58                                               France
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 928                         Black                           working out
# 909                        Yellow                         With friends
# 416                          Blue                          Lift weights
# 976                         Green                        Playing Guitar
# 243                          Blue                              Chatting
# ...                           ...                                   ...
# 898                        purple                                 Sleep
# 1060                        Black                        Watching shows
# 453                         green                               reading
# 215                         white                          social media
# 58                            Red                               Reading
#
#      What genre of music do you like the most?  \
# 928                                  Reggaeton
# 909                                        Rap
# 416                                        EDM
# 976                                      Indie
# 243                                       Folk
# ...                                        ...
# 898                                   pop-rock
# 1060                                       Pop
# 453                                        pop
# 215                                        RMB
# 58                               Dark Romantic
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 928                                                Hawk
# 909                                            A monkey
# 416                                                Bear
# 976                                    Gorilla. Gorilla
# 243                                               Otter
# ...                                                 ...
# 898                                                 Cat
# 1060                                              Panda
# 453                                                 cat
# 215                                                 cat
# 58                                            Black cat
#
#      What do you think is the hardest major at UIUC?  \
# 928                                     Neuroscience
# 909                                Computer Science
# 416                                               CS
# 976                           Electrical Engineering
# 243                                               CS
# ...                                              ...
# 898                             computer engineering
# 1060                                         Physics
# 453                                              ECE
# 215                                               CS
# 58                            Mechanical Engineering
#
#      Who is your favorite music artist?  \
# 928                                Feid
# 909                        Travis Scott
# 416                               Kanii
# 976                             Mt. Joy
# 243                             Chen Li
# ...                                 ...
# 898                          the marias
# 1060                         Kanye West
# 453                        Taylor Swift
# 215                        Taylor Swift
# 58                         Lana Del Rey
#
#      What's your favorite social media app?  \
# 928                               Instagram
# 909                                Snapchat
# 416                                   Insta
# 976                               Instagram
# 243                               Instagram
# ...                                     ...
# 898                               Instagram
# 1060                                Discord
# 453                               instagram
# 215                               Instagram
# 58                                Instagram
#
#      What is your favorite game to play (either video game or IRL)?  \
# 928                                              soccer
# 909                                          Basketball
# 416                                              Roblox
# 976                                            Football
# 243                                                 UNO
# ...                                                 ...
# 898                                    animal crossing
# 1060                                              Poker
# 453                                              tennis
# 215                                          vedio game
# 58                               The Last of Us Part II
#
#      Where is your dream vacation spot?
# 928                           Barcelona
# 909                           Maldives
# 416                              Mexico
# 976                               Italy
# 243                              Cancun
# ...                                 ...
# 898                               Japan
# 1060                              Japan
# 453                             Toronto
# 215                              Cancun
# 58                               France
#
# [326 rows x 150 columns]

# %% [markdown]
# ## Part 3.4:
#
# Create a `df2_control` group that contains the other half of the rows from `df2`.

# %%
df2_control =  df2[ ~df2.index.isin(df2_treatment.index) ]
df2_control
# Out:
#              Name          Lab When flipping a coin, heads or tails?  \
# 0     Prof. Karle     AL1, AL2                                 Heads
# 1      Prof. Wade     AL1, AL2                                 Tails
# 2        Angelina          Y13                                 Tails
# 4          Sneha           Y17                                 Tails
# 8            Eman          Y11                                 Heads
# ...           ...          ...                                   ...
# 1041       Tianqi          Y31                                 Tails
# 1045       Monica          Y06                                 Heads
# 1048       Molina          Y09                                 Heads
# 1052      CA Soph  Y05 Y07 Y14                                 Heads
# 1067      Chinmay          Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 0                      Not First Year
# 1                      Not First Year
# 2                  First Year at UIUC
# 4                  First Year at UIUC
# 8                  First Year at UIUC
# ...                               ...
# 1041                   Not First Year
# 1045               First Year at UIUC
# 1048               First Year at UIUC
# 1052                   Not First Year
# 1067               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 0                                             Chocolate
# 1                                               Vanilla
# 2                                               Vanilla
# 4                                               Vanilla
# 8                                             Chocolate
# ...                                                 ...
# 1041                                            Vanilla
# 1045                                            Vanilla
# 1048                                          Chocolate
# 1052                                          Chocolate
# 1067                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 0                             Night                               Even
# 1                             Night                                Odd
# 2                           Morning                               Even
# 4                             Night                               Even
# 8                           Morning                               Even
# ...                             ...                                ...
# 1041                        Morning                                Odd
# 1045                        Morning                               Even
# 1048                          Night                               Even
# 1052                          Night                               Even
# 1067                          Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 0                    No                          Summer
# 1                   Yes                          Winter
# 2                   Yes                          Summer
# 4                    No                          Summer
# 8                    No                          Summer
# ...                 ...                             ...
# 1041                 No                          Winter
# 1045                 No                          Summer
# 1048                 No                          Summer
# 1052                Yes                          Winter
# 1067                 No                          Summer
#
#      Are you a business major?  ...  \
# 0                           No  ...
# 1                           No  ...
# 2                           No  ...
# 4                          Yes  ...
# 8                           No  ...
# ...                        ...  ...
# 1041                        No  ...
# 1045                        No  ...
# 1048                        No  ...
# 1052                        No  ...
# 1067                        No  ...
#
#      Besides the US, what country would you like to live in?  \
# 0                                          The Maldives
# 1                                                Sweden
# 2                                            Hong Kong
# 4                                                Canada
# 8                                                   UAE
# ...                                                 ...
# 1041                                          Singapore
# 1045                                              Italy
# 1048                                        Switzerland
# 1052                                            Finland
# 1067                                              India
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 0                            pink                         water skiing!
# 1                          Purple                           Programming
# 2                            Pink                        Watching shows
# 4                           Green                 Reading or crocheting
# 8                             Red                Hang out with friends
# ...                           ...                                   ...
# 1041                        Black                             Composing
# 1045                         Grey                               reading
# 1048                       Purple                               Singing
# 1052                          Red                          With friends
# 1067                         Blue                                 Music
#
#      What genre of music do you like the most?  \
# 0                                          pop
# 1                                          Pop
# 2                                          r&b
# 4                                     Pop Rock
# 8                                          R&B
# ...                                        ...
# 1041      Art rock/jazz pop/experimental noise
# 1045                                       Rap
# 1048                                       Pop
# 1052                                     Indie
# 1067                                       Rap
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 0                                                 sloth
# 1                                                   Fox
# 2                                                 Tiger
# 4                                               Penguin
# 8                                               Unicorn
# ...                                                 ...
# 1041                                               Deer
# 1045                                                cat
# 1048                                                Cat
# 1052                                              Shark
# 1067                                                Dog
#
#      What do you think is the hardest major at UIUC?  \
# 0                                   Computer Science
# 1                                   Computer Science
# 2                             Aerospace engineering
# 4                                   Computer Science
# 8                                            Physics
# ...                                              ...
# 1041                                Computer Science
# 1045                                              CS
# 1048                                              CS
# 1052                             Bioengineering + CS
# 1067                                Computer Science
#
#      Who is your favorite music artist?  \
# 0                          Taylor Swift
# 1                          Taylor Swift
# 2                         Ashley Alisha
# 4                       Imagine Dragons
# 8                                   SZA
# ...                                 ...
# 1041                        Leehom Wang
# 1045                           Big Sean
# 1048                           Jay Chou
# 1052                                BTS
# 1067                       Travis Scott
#
#      What's your favorite social media app?  \
# 0                                 Instagram
# 1                                   YouTube
# 2                                     Insta
# 4                                 Instagram
# 8                                 Instagram
# ...                                     ...
# 1041                                Discord
# 1045                                 tiktok
# 1048                                    Ins
# 1052                                 TikTok
# 1067                              Instagram
#
#      What is your favorite game to play (either video game or IRL)?  \
# 0                                            volleyball
# 1                                              Factorio
# 2                                                   NaN
# 4                                            Beat Saber
# 8                                                  Sims
# ...                                                 ...
# 1041                                          Max Payne
# 1045                                           fortnite
# 1048                                         Video game
# 1052                                          Minecraft
# 1067                                             Tennis
#
#      Where is your dream vacation spot?
# 0                          The Maldives
# 1                                Acadia
# 2                       Southern France
# 4                                 Italy
# 8                               Greece
# ...                                 ...
# 1041                          Singapore
# 1045                              Italy
# 1048                        Switzerland
# 1052                            Croatia
# 1067                             Monaco
#
# [326 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df2_treatment' in vars() ), "You do not have a DataFrame called `df2_treatment`."
assert( 'df2_control' in vars() ), "You do not have a DataFrame called `df2_control`."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df2_control.index) ]) == 0), "The `df2_treatment` and `df2_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df1.index) ]) == 0), "The `df2_treatment` and `df1` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_control.index) & df.index.isin(df1.index) ]) == 0), "The `df2_control` and `df1` groups have some overlap!  There must be no overlap."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.5:
#
# Finally, read the guide: **Combining DataFrames by Concatenation** (https://discovery.cs.illinois.edu/guides/Combining-DataFrames/Combining-DataFrames-by-Concatenation/) to learn how to combine `df1_treatment` and `df2_treatment` together into one group called `treatment`.
#
# FYI, you will not need to reset the index here!

# %%
treatment= pd.concat([df1_treatment, df2_treatment])

treatment
# Out:
#             Name       Lab When flipping a coin, heads or tails?  \
# 360         Ryan       Y36                                 Heads
# 593     Nikitha        Y15                                 Heads
# 960     TA Omkar  Y11, Y26                                 Heads
# 964        Jiayi       Y03                                 Heads
# 469   CA Lyndsey       Y08                                 Heads
# ...          ...       ...                                   ...
# 898         Gaby       Y08                                 Tails
# 1060    TA Jimmy       Y21                                 Tails
# 453      Chantal       Y10                                 Heads
# 215       Ashley       Y23                                 Heads
# 58        Olivia       Y30                                 Tails
#
#      Is this your first year at UIUC?  \
# 360                First Year at UIUC
# 593                First Year at UIUC
# 960                    Not First Year
# 964                First Year at UIUC
# 469                    Not First Year
# ...                               ...
# 898                    Not First Year
# 1060               First Year at UIUC
# 453                    Not First Year
# 215                First Year at UIUC
# 58                 First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 360                                           Chocolate
# 593                                           Chocolate
# 960                                           Chocolate
# 964                                           Chocolate
# 469                                           Chocolate
# ...                                                 ...
# 898                                             Vanilla
# 1060                                          Chocolate
# 453                                             Vanilla
# 215                                           Chocolate
# 58                                              Vanilla
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 360                           Night                               Even
# 593                         Morning                                Odd
# 960                         Morning                               Even
# 964                           Night                               Even
# 469                         Morning                               Even
# ...                             ...                                ...
# 898                           Night                               Even
# 1060                          Night                               Even
# 453                         Morning                                Odd
# 215                           Night                               Even
# 58                          Morning                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 360                  No                          Summer
# 593                  No                          Summer
# 960                  No                          Summer
# 964                  No                          Summer
# 469                 Yes                          Summer
# ...                 ...                             ...
# 898                 Yes                          Winter
# 1060                 No                          Summer
# 453                 Yes                          Winter
# 215                 Yes                          Summer
# 58                  Yes                          Winter
#
#      Are you a business major?  ...  \
# 360                         No  ...
# 593                         No  ...
# 960                         No  ...
# 964                         No  ...
# 469                         No  ...
# ...                        ...  ...
# 898                         No  ...
# 1060                        No  ...
# 453                         No  ...
# 215                         No  ...
# 58                          No  ...
#
#      Besides the US, what country would you like to live in?  \
# 360                                              Canada
# 593                                               spain
# 960                                               india
# 964                                           Australia
# 469                                               italy
# ...                                                 ...
# 898                                              Mexico
# 1060                                                 UK
# 453                                              Canada
# 215                                               China
# 58                                               France
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 360                          blue                       watching videos
# 593                   blue +green                        sleep and read
# 960                          teal                              sleeping
# 964                          Blue                       watching movies
# 469                           red                              shopping
# ...                           ...                                   ...
# 898                        purple                                 Sleep
# 1060                        Black                        Watching shows
# 453                         green                               reading
# 215                         white                          social media
# 58                            Red                               Reading
#
#      What genre of music do you like the most?  \
# 360                                      j pop
# 593                                        pop
# 960                                  bollywood
# 964                                        Pop
# 469                                        pop
# ...                                        ...
# 898                                   pop-rock
# 1060                                       Pop
# 453                                        pop
# 215                                        RMB
# 58                               Dark Romantic
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 360                                                 cat
# 593                                             panther
# 960                                                 NaN
# 964                                                 Cat
# 469                                            shih tzu
# ...                                                 ...
# 898                                                 Cat
# 1060                                              Panda
# 453                                                 cat
# 215                                                 cat
# 58                                            Black cat
#
#      What do you think is the hardest major at UIUC?  \
# 360                                      Mathematics
# 593                                          physics
# 960                                              ECE
# 964                                               CS
# 469                                 computer science
# ...                                              ...
# 898                             computer engineering
# 1060                                         Physics
# 453                                              ECE
# 215                                               CS
# 58                            Mechanical Engineering
#
#      Who is your favorite music artist?  \
# 360                              millet
# 593                         don toliver
# 960                        arijit singh
# 964                            Tao, Zhe
# 469                       gracie abrams
# ...                                 ...
# 898                          the marias
# 1060                         Kanye West
# 453                        Taylor Swift
# 215                        Taylor Swift
# 58                         Lana Del Rey
#
#      What's your favorite social media app?  \
# 360                               instagram
# 593                                 tik tok
# 960                               instagram
# 964                                  TikTok
# 469                               instagram
# ...                                     ...
# 898                               Instagram
# 1060                                Discord
# 453                               instagram
# 215                               Instagram
# 58                                Instagram
#
#      What is your favorite game to play (either video game or IRL)?  \
# 360                                           Persona 5
# 593                                              tetris
# 960                                                fifa
# 964                                        It Takes Two
# 469                                          pickleball
# ...                                                 ...
# 898                                    animal crossing
# 1060                                              Poker
# 453                                              tennis
# 215                                          vedio game
# 58                               The Last of Us Part II
#
#      Where is your dream vacation spot?
# 360                              Hawaii
# 593                          carribeans
# 960                               spain
# 964                               China
# 469                               italy
# ...                                 ...
# 898                               Japan
# 1060                              Japan
# 453                             Toronto
# 215                              Cancun
# 58                               France
#
# [534 rows x 150 columns]

# %% [markdown]
# ## Part 3.6:
#
# Using the same technique, combine `df1_control` and `df2_control` together into one group called `control`:

# %%
control = pd.concat([df1_control, df2_control])
control
# Out:
#           Name          Lab When flipping a coin, heads or tails?  \
# 3     TA Tyler          Y07                                 Tails
# 9       Amanda          Y23                                 Heads
# 16     Aaliyay          Y30                                 Heads
# 17      Albert          Y10                                 Heads
# 18       Colin          Y07                                 Heads
# ...        ...          ...                                   ...
# 1041    Tianqi          Y31                                 Tails
# 1045    Monica          Y06                                 Heads
# 1048    Molina          Y09                                 Heads
# 1052   CA Soph  Y05 Y07 Y14                                 Heads
# 1067   Chinmay          Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 3                      Not First Year
# 9                  First Year at UIUC
# 16                 First Year at UIUC
# 17                 First Year at UIUC
# 18                 First Year at UIUC
# ...                               ...
# 1041                   Not First Year
# 1045               First Year at UIUC
# 1048               First Year at UIUC
# 1052                   Not First Year
# 1067               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 3                                             Chocolate
# 9                                               Vanilla
# 16                                              Vanilla
# 17                                              Vanilla
# 18                                              Vanilla
# ...                                                 ...
# 1041                                            Vanilla
# 1045                                            Vanilla
# 1048                                          Chocolate
# 1052                                          Chocolate
# 1067                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 3                             Night                               Even
# 9                             Night                               Even
# 16                            Night                               Even
# 17                            Night                                Odd
# 18                            Night                                Odd
# ...                             ...                                ...
# 1041                        Morning                                Odd
# 1045                        Morning                               Even
# 1048                          Night                               Even
# 1052                          Night                               Even
# 1067                          Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 3                    No                          Winter
# 9                   Yes                          Summer
# 16                  Yes                          Summer
# 17                   No                          Summer
# 18                  Yes                          Summer
# ...                 ...                             ...
# 1041                 No                          Winter
# 1045                 No                          Summer
# 1048                 No                          Summer
# 1052                Yes                          Winter
# 1067                 No                          Summer
#
#      Are you a business major?  ...  \
# 3                           No  ...
# 9                          Yes  ...
# 16                          No  ...
# 17                          No  ...
# 18                         Yes  ...
# ...                        ...  ...
# 1041                        No  ...
# 1045                        No  ...
# 1048                        No  ...
# 1052                        No  ...
# 1067                        No  ...
#
#      Besides the US, what country would you like to live in?  \
# 3                                                Canada
# 9                                                   NaN
# 16                                              Canada
# 17                                               Poland
# 18                                                italy
# ...                                                 ...
# 1041                                          Singapore
# 1045                                              Italy
# 1048                                        Switzerland
# 1052                                            Finland
# 1067                                              India
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 3                          Orange                              Terraria
# 9                           Green                     Watching TV shows
# 16                           blue                              on phone
# 17                            Red                                Soccer
# 18                     dark green                       watching movies
# ...                           ...                                   ...
# 1041                        Black                             Composing
# 1045                         Grey                               reading
# 1048                       Purple                               Singing
# 1052                          Red                          With friends
# 1067                         Blue                                 Music
#
#      What genre of music do you like the most?  \
# 3                                     Pop rock
# 9                                          Pop
# 16                                         rnb
# 17                                         Rap
# 18                                       indie
# ...                                        ...
# 1041      Art rock/jazz pop/experimental noise
# 1045                                       Rap
# 1048                                       Pop
# 1052                                     Indie
# 1067                                       Rap
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 3                                                   Bee
# 9                                               Dolphin
# 16                                                 bird
# 17                                                Tiger
# 18                                                  dog
# ...                                                 ...
# 1041                                               Deer
# 1045                                                cat
# 1048                                                Cat
# 1052                                              Shark
# 1067                                                Dog
#
#      What do you think is the hardest major at UIUC?  \
# 3                               Chemical Engineering
# 9                                        Engineering
# 16                             aerospace engineering
# 17                              Chemical Engineering
# 18                                  computer science
# ...                                              ...
# 1041                                Computer Science
# 1045                                              CS
# 1048                                              CS
# 1052                             Bioengineering + CS
# 1067                                Computer Science
#
#      Who is your favorite music artist?  \
# 3                            Billy Joel
# 9                                   NaN
# 16                          Frank Ocean
# 17                         Travis Scott
# 18                              wallows
# ...                                 ...
# 1041                        Leehom Wang
# 1045                           Big Sean
# 1048                           Jay Chou
# 1052                                BTS
# 1067                       Travis Scott
#
#      What's your favorite social media app?  \
# 3                                    Reddit
# 9                                 Instagram
# 16                                   tiktok
# 17                                Instagram
# 18                                instagram
# ...                                     ...
# 1041                                Discord
# 1045                                 tiktok
# 1048                                    Ins
# 1052                                 TikTok
# 1067                              Instagram
#
#      What is your favorite game to play (either video game or IRL)?  \
# 3                                              Terraria
# 9                                                   NaN
# 16                                               sims 4
# 17                                               Soccer
# 18                                           mario kart
# ...                                                 ...
# 1041                                          Max Payne
# 1045                                           fortnite
# 1048                                         Video game
# 1052                                          Minecraft
# 1067                                             Tennis
#
#      Where is your dream vacation spot?
# 3                          My apartment
# 9                                 Italy
# 16                               eurpoe
# 17                              Croatia
# 18                               hawaii
# ...                                 ...
# 1041                          Singapore
# 1045                              Italy
# 1048                        Switzerland
# 1052                            Croatia
# 1067                             Monaco
#
# [533 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."
assert(
  (len(treatment) + len(control) == len(df1) + len(df2)) or 
  (len(treatment) + len(control) == len(df))
), f"Not everyone in the dataset (or everyone who responded to the question being blocked) is included in one of the two groups -- someone is missing! :(\nPeople in treatment group: {len(treatment)}\nPeople in control group: {len(control)}\nTotal in treatment+control group: {len(control) + len(treatment)}\n== vs ==\nTotal people in dataset: {len(df)}\nTotal people with data for blocking: {len(df1) + len(df2)}"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
